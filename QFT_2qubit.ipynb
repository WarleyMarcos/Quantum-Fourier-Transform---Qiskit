# %% [markdown]
# ## Algoritmo de Transformada Quântica de Fourier para 2qubits
#
# Estados em que a QFT foi testada:
#
#
#
# *  $\vert 00 \rangle$, $\vert 01 \rangle$,  $\vert 10 \rangle$ e $\vert 11 \rangle$;
#
#
#
# *  $\vert 0 \rangle \vert + \rangle$, $\vert + \rangle \vert 0 \rangle$,  $\vert 0 \rangle \vert - \rangle$ e $\vert - \rangle \vert 0 \rangle$;
#
#
#
# *  $\vert 1 \rangle \vert + \rangle$, $\vert + \rangle \vert 1 \rangle$,  $\vert 1 \rangle \vert - \rangle$ e $\vert - \rangle \vert 1 \rangle$;
#
#
#
# *  $\vert + \rangle \vert + \rangle$, $\vert + \rangle \vert + \rangle$,  $\vert + \rangle \vert - \rangle$ e $\vert - \rangle \vert + \rangle$;
#
#
#
# *  $\frac{\vert 00 \rangle + \vert 11 \rangle}{\sqrt{2}}$, $\frac{\vert 01 \rangle + \vert 10 \rangle}{\sqrt{2}}$,  $\frac{\vert 00 \rangle - \vert 11 \rangle}{\sqrt{2}}$ e $\frac{\vert 01 \rangle - \vert 10 \rangle}{\sqrt{2}}$;
#
#
#
# * Estado aleatório.
#
#
#
# $$\vert + \rangle = \frac{\vert 0 \rangle + \vert 1 \rangle}{\sqrt{2}}$$
#
# $$\vert - \rangle = \frac{\vert 0 \rangle - \vert 1 \rangle}{\sqrt{2}}$$.

# %%
#------------------------------------------------------------------------
# FUNCAO QUE MONTA O CIRCUITO DA QFT DE '2' QUBITS:
#------------------------------------------------------------------------
def QFT_2qubit(Changing_initial_state):
    from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
#------------------------------
# CARACTERISTICAS GERAIS DO CIRCUITO
    nQ = 2 # <-- NUMERO DE QUBITS
    nC = 2 # <-- NUMERO DE BITS CLASSICOS
    Q  = QuantumRegister(  nQ, name = 'j')
    C  = ClassicalRegister(nC, name = 'c')
    QC = QuantumCircuit(Q, C, name = "QFT_2qubit")
#------------------------------
#PREPARAÇÃO DO ESTADO INCIAL
#------------------------------     
    if Changing_initial_state == 0: # |00>
        None
    if Changing_initial_state == 1: # |01>
        QC.x(Q[1]) # <-- PORTA 'X' NO QUBIT 1
        QC.barrier()
    if Changing_initial_state == 2: # |10>
        QC.x(Q[0]) # <-- PORTA 'X' NO QUBIT 0
        QC.barrier()
    if Changing_initial_state == 3: # |11>
        QC.x(Q[0]) # <-- PORTA 'X' NO QUBIT 0
        QC.x(Q[1]) # <-- PORTA 'X' NO QUBIT 1
        QC.barrier()
#------------------------------
    if Changing_initial_state == 4: # |0>|+>
        QC.h(Q[1]) # <-- PORTA 'H' NO QUBIT 1
        QC.barrier()
    if Changing_initial_state == 5: # |+>|0>
        QC.h(Q[0]) # <-- PORTA 'H' NO QUBIT 0
        QC.barrier()
    if Changing_initial_state == 6: # |0>|->
        QC.x(Q[1]) # <-- PORTA 'X' NO QUBIT 1
        QC.h(Q[1]) # <-- PORTA 'H' NO QUBIT 1
        QC.barrier()
    if Changing_initial_state == 7: # |->|0>
        QC.x(Q[0]) # <-- PORTA 'X' NO QUBIT 0
        QC.h(Q[0]) # <-- PORTA 'H' NO QUBIT 0
        QC.barrier()
#------------------------------
    if Changing_initial_state == 8: # |1>|+>
        QC.x(Q[0]) # <-- PORTA 'X' NO QUBIT 0
        QC.h(Q[1]) # <-- PORTA 'H' NO QUBIT 1
        QC.barrier()
    if Changing_initial_state == 9: # |+>|1>
        QC.h(Q[0]) # <-- PORTA 'H' NO QUBIT 0
        QC.x(Q[1]) # <-- PORTA 'X' NO QUBIT 1
        QC.barrier()
    if Changing_initial_state == 10: # |1>|->
        QC.x(Q[0]) # <-- PORTA 'X' NO QUBIT 0
        QC.x(Q[1]) # <-- PORTA 'X' NO QUBIT 1
        QC.h(Q[1]) # <-- PORTA 'H' NO QUBIT 1
        QC.barrier()
    if Changing_initial_state == 11: # |->|1>
        QC.x(Q[0]) # <-- PORTA 'X' NO QUBIT 0
        QC.h(Q[0]) # <-- PORTA 'H' NO QUBIT 0
        QC.x(Q[1]) # <-- PORTA 'X' NO QUBIT 1
        QC.barrier()
#------------------------------
    if Changing_initial_state == 12: # |+>|+>
        QC.h(Q[0]) # <-- PORTA 'H' NO QUBIT 0
        QC.h(Q[1]) # <-- PORTA 'H' NO QUBIT 1
        QC.barrier()
    if Changing_initial_state == 13: # |+>|->
        QC.h(Q[0]) # <-- PORTA 'H' NO QUBIT 0
        QC.x(Q[1]) # <-- PORTA 'X' NO QUBIT 1
        QC.h(Q[1]) # <-- PORTA 'H' NO QUBIT 1
        QC.barrier()
    if Changing_initial_state == 14: # |->|+>
        QC.x(Q[0]) # <-- PORTA 'X' NO QUBIT 0
        QC.h(Q[0]) # <-- PORTA 'H' NO QUBIT 0
        QC.h(Q[1]) # <-- PORTA 'H' NO QUBIT 1
        QC.barrier()
    if Changing_initial_state == 15: # |->|->
        QC.x(Q[0]) # <-- PORTA 'X' NO QUBIT 0
        QC.h(Q[0]) # <-- PORTA 'H' NO QUBIT 0
        QC.x(Q[1]) # <-- PORTA 'X' NO QUBIT 1
        QC.h(Q[1]) # <-- PORTA 'H' NO QUBIT 1
        QC.barrier()
#------------------------------
    if Changing_initial_state == 16: # |00> + |11>
        QC.h(Q[0])
        QC.cx(Q[0], Q[1])
        QC.barrier()
    if Changing_initial_state == 17: # |01> + |10>
        QC.x(Q[1]) # <-- PORTA 'X' NO QUBIT 1
        QC.h(Q[0])
        QC.cx(Q[0], Q[1])
        QC.barrier()
    if Changing_initial_state == 18: # |10> - |11>
        QC.x(Q[0]) # <-- PORTA 'X' NO QUBIT 0
        QC.h(Q[0])
        QC.cx(Q[0], Q[1])
        QC.barrier()
    if Changing_initial_state == 19: # |01> + |10>
        QC.x(Q[0]) # <-- PORTA 'X' NO QUBIT 0
        QC.x(Q[1]) # <-- PORTA 'X' NO QUBIT 1
        QC.h(Q[0])
        QC.cx(Q[0], Q[1])
        QC.barrier()
#------------------------------
#PREPARAÇÃO DO ESTADO INCIAL: ESTADO ALEATORIO
#------------------------------
    if Changing_initial_state == 20: 
        from qiskit.visualization import plot_state_qsphere
        from qiskit.quantum_info import Statevector, random_statevector
        psi_random = random_statevector(4)
        QC.initialize(psi_random.data, [0,1])
        QC.barrier()
#------------------------------
#APLICANDO A QFT
#------------------------------
    QC.h(Q[1])  # <-- PORTA 'H' NO QUBIT 1
    Rk(QC, Q[0], Q[1], 2, 1.0)
    QC.barrier()
#------------------------------
    QC.h(Q[0])  # <-- PORTA 'H' NO QUBIT 0
    QC.barrier()
#------------------------------
# PORTA SWAP:
#------------------------------
    QC.swap( Q[0], Q[1] )
#------------------------------
    QC.barrier()
    QC.measure(Q, C) 
#------------------------------  
    print('QFT_2qubit(): FUNCIONA')
#------------------------------
    return QC


#------------------------------------------------------------------------
# FUNCAO QUE DEFINE A PORTA Rk USANDO A PORTA cu1:
#------------------------------------------------------------------------
def Rk(QC, Q_CONTROL, Q_TARGET, k, a):
    import math as MT; PI = MT.pi
    QC.cu1( a*2.0*PI/2.0**k, Q_CONTROL, Q_TARGET)
    return None

# %%
#------------------------------------------------------------------------
# FUNCAO QUE EXECUTA O CIRCUITO NA MAQUINA LOCAL:
#------------------------------------------------------------------------
def SIMULADOR_LOCAL(QC, N_SHOTS, BACKEND_NAME):
    from qiskit  import Aer
    from qiskit  import execute
#--------------
    F_NAME = '\'SIMULADOR_LOCAL()\''
    BACKEND = Aer.get_backend(BACKEND_NAME)
#-----------------------------------------------------------------------
    EXP = execute(QC, BACKEND, shots=N_SHOTS)
    RESULT = EXP.result()
    print(' RESULTS:')
#    print('   EXP.result():', RESULT) # <-- IMPRIMI UM MONTE DE COISAS
    print('   backend_name:', RESULT.backend_name, end =' |')
    print('   status:',       RESULT.status, end =' |')
    print('   success:',      RESULT.success)
#    print('   data:',         RESULT.data) # <-- IMPRIMI UM MONTE DE COISAS
    print('   get_counts():', RESULT.get_counts() )
#-----------------------------------------------------------------------
    print(' ---------- FIM DA FUNCAO %s---------- '% F_NAME)
    return RESULT.get_counts()

# %%
QC_QFT_2qubit0 = QFT_2qubit(0)
QC_QFT_2qubit1 = QFT_2qubit(1)
QC_QFT_2qubit2 = QFT_2qubit(2)
QC_QFT_2qubit3 = QFT_2qubit(3)
# Out:
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA
# <ipython-input-1-4bf8e917aea7>:140: DeprecationWarning: The QuantumCircuit.cu1 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use the QuantumCircuit.cp method instead, which acts identically.
#   QC.cu1( a*2.0*PI/2.0**k, Q_CONTROL, Q_TARGET)

# %%
display(QC_QFT_2qubit0.draw(output='mpl'))
display(QC_QFT_2qubit1.draw(output='mpl'))
display(QC_QFT_2qubit2.draw(output='mpl'))
display(QC_QFT_2qubit3.draw(output='mpl'))

# %%
QC_QFT_2qubit4 = QFT_2qubit(4)
QC_QFT_2qubit5 = QFT_2qubit(5)
QC_QFT_2qubit6 = QFT_2qubit(6)
QC_QFT_2qubit7 = QFT_2qubit(7)
QC_QFT_2qubit8 = QFT_2qubit(8)
QC_QFT_2qubit9 = QFT_2qubit(9)
QC_QFT_2qubit10 = QFT_2qubit(10)
QC_QFT_2qubit11 = QFT_2qubit(11)
QC_QFT_2qubit12 = QFT_2qubit(12)
QC_QFT_2qubit13 = QFT_2qubit(13)
QC_QFT_2qubit14 = QFT_2qubit(14)
QC_QFT_2qubit15 = QFT_2qubit(15)
# Out:
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA

# %%
display(QC_QFT_2qubit4.draw(output='mpl'))
display(QC_QFT_2qubit5.draw(output='mpl'))
display(QC_QFT_2qubit6.draw(output='mpl'))
display(QC_QFT_2qubit7.draw(output='mpl'))
display(QC_QFT_2qubit8.draw(output='mpl'))
display(QC_QFT_2qubit9.draw(output='mpl'))
display(QC_QFT_2qubit10.draw(output='mpl'))
display(QC_QFT_2qubit11.draw(output='mpl'))
display(QC_QFT_2qubit12.draw(output='mpl'))
display(QC_QFT_2qubit13.draw(output='mpl'))
display(QC_QFT_2qubit14.draw(output='mpl'))
display(QC_QFT_2qubit15.draw(output='mpl'))

# %%
QC_QFT_2qubit16 = QFT_2qubit(16)
QC_QFT_2qubit17 = QFT_2qubit(17)
QC_QFT_2qubit18 = QFT_2qubit(18)
QC_QFT_2qubit19 = QFT_2qubit(19)
# Out:
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA
# QFT_2qubit(): FUNCIONA

# %%
display(QC_QFT_2qubit16.draw(output='mpl'))
display(QC_QFT_2qubit17.draw(output='mpl'))
display(QC_QFT_2qubit18.draw(output='mpl'))
display(QC_QFT_2qubit19.draw(output='mpl'))

# %%
QC_QFT_2qubit20 = QFT_2qubit(20)
# Out:
# QFT_2qubit(): FUNCIONA

# %%
display(QC_QFT_2qubit20.draw(output='mpl'))

# %% [markdown]
# ## Simulando na máquina Local

# %%
#----------------------------------------------
# FUNCAO PARA SIMULAR UM CIRCUITO QUANTICO NA
# MAQUINA LOCAL
#----------------------------------------------
def SIMULADOR_LOCAL(QC, N_SHOTS, BACKEND_NAME):
    from qiskit  import Aer
    from qiskit  import execute
#--------------
    F_NAME = '\'SIMULADOR_LOCAL()\''
    BACKEND = Aer.get_backend(BACKEND_NAME)
#-----------------------------------------------------------------------
    EXP = execute(QC, BACKEND, shots=N_SHOTS)
    RESULT = EXP.result()
    print(' RESULTS:')
#    print('   EXP.result():', RESULT) # <-- IMPRIMI UM MONTE DE COISAS
    print('   backend_name:', RESULT.backend_name, end =' |')
    print('   status:',       RESULT.status, end =' |')
    print('   success:',      RESULT.success)
#    print('   data:',         RESULT.data) # <-- IMPRIMI UM MONTE DE COISAS
    print('   get_counts():', RESULT.get_counts() )
#-----------------------------------------------------------------------
    print(' ---------- FIM DA FUNCAO %s---------- '% F_NAME)
    return RESULT.get_counts()

# %%
#------------------------------------------------------------------------
# FUNCAO PARA CRIAR O HISTOGRAMA:
#------------------------------------------------------------------------
def PLOT_HISTOGRAMS( DATA ):
    from qiskit.tools.visualization import plot_histogram
    BAR_LABELS = True # <-- MOSTRAR AS PROBABILIDADES ACIMA DAS BARRAS DO HISTOGRAMA
    HIST = plot_histogram( DATA, bar_labels = BAR_LABELS, figsize = (15, 4) )
    display(HIST)
    return None

# %%
#------------------------------------------------------------------------
# SIMULANDO OS CIRCUITOS:
#------------------------------------------------------------------------
N_SHOTS = 1000000 #2**(13)
BACKEND_NAME = "qasm_simulator"

DADOS_0 = SIMULADOR_LOCAL(QC_QFT_2qubit0, N_SHOTS, BACKEND_NAME)
DADOS_1 = SIMULADOR_LOCAL(QC_QFT_2qubit1, N_SHOTS, BACKEND_NAME)
DADOS_2 = SIMULADOR_LOCAL(QC_QFT_2qubit2, N_SHOTS, BACKEND_NAME)
DADOS_3 = SIMULADOR_LOCAL(QC_QFT_2qubit3, N_SHOTS, BACKEND_NAME)
DADOS_4 = SIMULADOR_LOCAL(QC_QFT_2qubit4, N_SHOTS, BACKEND_NAME)
DADOS_5 = SIMULADOR_LOCAL(QC_QFT_2qubit5, N_SHOTS, BACKEND_NAME)
DADOS_6 = SIMULADOR_LOCAL(QC_QFT_2qubit6, N_SHOTS, BACKEND_NAME)
DADOS_7 = SIMULADOR_LOCAL(QC_QFT_2qubit7, N_SHOTS, BACKEND_NAME)
DADOS_8 = SIMULADOR_LOCAL(QC_QFT_2qubit8, N_SHOTS, BACKEND_NAME)
DADOS_9 = SIMULADOR_LOCAL(QC_QFT_2qubit9, N_SHOTS, BACKEND_NAME)
DADOS_10 = SIMULADOR_LOCAL(QC_QFT_2qubit10, N_SHOTS, BACKEND_NAME)
DADOS_11 = SIMULADOR_LOCAL(QC_QFT_2qubit11, N_SHOTS, BACKEND_NAME)
DADOS_12 = SIMULADOR_LOCAL(QC_QFT_2qubit12, N_SHOTS, BACKEND_NAME)
DADOS_13 = SIMULADOR_LOCAL(QC_QFT_2qubit13, N_SHOTS, BACKEND_NAME)
DADOS_14 = SIMULADOR_LOCAL(QC_QFT_2qubit14, N_SHOTS, BACKEND_NAME)
DADOS_15 = SIMULADOR_LOCAL(QC_QFT_2qubit15, N_SHOTS, BACKEND_NAME)
DADOS_16 = SIMULADOR_LOCAL(QC_QFT_2qubit16, N_SHOTS, BACKEND_NAME)
DADOS_17 = SIMULADOR_LOCAL(QC_QFT_2qubit17, N_SHOTS, BACKEND_NAME)
DADOS_18 = SIMULADOR_LOCAL(QC_QFT_2qubit18, N_SHOTS, BACKEND_NAME)
DADOS_19 = SIMULADOR_LOCAL(QC_QFT_2qubit19, N_SHOTS, BACKEND_NAME)
DADOS_20 = SIMULADOR_LOCAL(QC_QFT_2qubit20, N_SHOTS, BACKEND_NAME)
# Out:
#  RESULTS:
#    backend_name: qasm_simulator |   status: COMPLETED |   success: True
#    get_counts(): {'11': 250224, '10': 249742, '01': 250281, '00': 249753}
#  ---------- FIM DA FUNCAO 'SIMULADOR_LOCAL()'----------
#  RESULTS:
#    backend_name: qasm_simulator |   status: COMPLETED |   success: True
#    get_counts(): {'00': 249867, '11': 249372, '01': 250604, '10': 250157}
#  ---------- FIM DA FUNCAO 'SIMULADOR_LOCAL()'----------
#  RESULTS:
#    backend_name: qasm_simulator |   status: COMPLETED |   success: True
#    get_counts(): {'11': 249795, '00': 250158, '10': 249902, '01': 250145}
#  ---------- FIM DA FUNCAO 'SIMULADOR_LOCAL()'----------
#  RESULTS:
#    backend_name: qasm_simulator |   status: COMPLETED |   success: True
#    get_counts(): {'00': 249151, '11': 249881, '10': 250962, '01': 250006}
#  ---------- FIM DA FUNCAO 'SIMULADOR_LOCAL()'----------
#  RESULTS:
#    backend_name: qasm_simulator |   status: COMPLETED |   success: True
# ...

# %%
import matplotlib.pyplot as plt
from qiskit.tools.visualization import plot_histogram;

# %%
plot_histogram( [DADOS_0], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_1], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_2], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_3], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_4], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_5], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_6], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_7], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_8], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_9], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_10], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_11], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_12], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_13], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_14], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_15], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_16], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_17], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_18], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_19], bar_labels = True, color='blue', figsize = (10, 6) )

# %%
plot_histogram( [DADOS_20], bar_labels = True, color='blue', figsize = (10, 6) )

# %% [markdown]
# ## Agora usando as máquinas da IBM

# %%
#-------------------------------------------------
# REGISTRANDO-SE NA IBM:
#------------------------------------------------
# Obs. : esta linha de codigo deve ser executada uma unica vez .
# Caso precise executa−la novamente RESTARTE o KERNEL.
from qiskit import IBMQ
#−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−
# Você pode obter o seu token em:
# https://quantum-computing.ibm.com/
QX_TOKEN = "Cole seu token aqui"
QX_URL = "https://quantumexperience.ng.bluemix.net/api"
#−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−−
try :
    IBMQ.save_account(QX_TOKEN)
    print('Registado com sucesso!')
except :
    print('Algo deu errado. \nVocê inseriu o token correto?')
# Out:
# configrc.store_credentials:WARNING:2021-09-12 10:41:22,458: Credentials already present. Set overwrite=True to overwrite.
# Registado com sucesso!

# %%
IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
from qiskit.tools.monitor import  backend_overview

backend_overview()
# Out:
# ibmq_manila                  ibmq_quito                  ibmq_belem
# -----------                  ----------                  ----------
# Num. Qubits:  5              Num. Qubits:  5             Num. Qubits:  5
# Pending Jobs: 7              Pending Jobs: 1             Pending Jobs: 3
# Least busy:   False          Least busy:   True          Least busy:   False
# Operational:  True           Operational:  True          Operational:  True
# Avg. T1:      142.1          Avg. T1:      91.7          Avg. T1:      90.4
# Avg. T2:      53.1           Avg. T2:      90.0          Avg. T2:      96.8
#
#
#
# ibmq_lima                    ibmq_bogota                  ibmq_santiago
# ---------                    -----------                  -------------
# Num. Qubits:  5              Num. Qubits:  5              Num. Qubits:  5
# Pending Jobs: 5              Pending Jobs: 4              Pending Jobs: 50
# Least busy:   False          Least busy:   False          Least busy:   False
# ...

# %%
#--------------------------------------------------
# FUNCAO QUE EXECUTA O CIRCUITO NA MAQUINA REMOTA:
#--------------------------------------------------
def SIMULADOR_REMOTO(QC, N_SHOTS, BACKEND_NAME):
    F_NAME = '\'SIMULADOR_REMOTO()\'';
    from qiskit               import IBMQ;
    from qiskit               import execute;
    from qiskit.tools.monitor import job_monitor;
#--------------
    PROVIDER = IBMQ.get_provider();
    BACKEND  = PROVIDER.get_backend(BACKEND_NAME);
#--------------
    STATUS  = BACKEND.status();
    if( STATUS.operational == False ):
        print(' FUNCAO %s DIZ:'% F_NAME );
        print(' ESTE BACKEND NAO ESTA OPERACIONAL NO MOMENTO, VEJA:');
        print("    STATUS.operational =",  STATUS);
        print(' ENCERRANDO'); return None;
#---------------
    EXP = execute(QC, BACKEND, shots=N_SHOTS);
    job_monitor(EXP, interval = 5);
#---------------
    RESULT = EXP.result();
    print(' RESULTS:');
    print('   backend_name:', RESULT.backend_name, end =' |');
    print('   status:',       RESULT.status, end =' |');
    print('   success:',      RESULT.success);
    print('   get_counts():', RESULT.get_counts() ); # print(' get_data() = ',   result.get_data(qc) );
#----------------
    print(' ---------- FIM DA FUNCAO %s---------- '% F_NAME);
    return RESULT.get_counts();

# %%
# NUMERO DE VEZES EM QUE O CIRCUITO EH EXECUTADO.
# 2**(13) EH O MAXIMO QUE A IBM ACEITA
N_SHOTS = 2**(13)

# ESCOLHENDO 6 BACKENDS COM FILA DE JOBS PEQUENA (OLHEI ACIMA).
# ibmq_qasm_simulator EH O SIMULADOR DA IBM, NORMALMENTE NAO DEMORA MUITO

BACKEND_NAME = "ibmq_manila";   DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit0, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";    DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit0, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";    DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit0, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";     DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit0, N_SHOTS, BACKEND_NAME);
#BACKEND_NAME = "ibmq_bogota";  DADOS_bogota   = SIMULADOR_REMOTO(QC_QFT_2qubit0, N_SHOTS, BACKEND_NAME); # Deu erro
BACKEND_NAME = "ibmq_santiago"; DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit0, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 2706, '01': 2163, '10': 1868, '11': 1455}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 2221, '01': 2116, '10': 1930, '11': 1925}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 2284, '01': 1674, '10': 1961, '11': 2273}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 1920, '01': 2539, '10': 1577, '11': 2156}
# ...

# %%
plot_histogram( [DADOS_0, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";   DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit1, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";    DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit1, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";    DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit1, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";     DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit1, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago"; DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit1, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 2108, '01': 1926, '10': 1992, '11': 2166}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 2195, '01': 2246, '10': 2083, '11': 1668}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 2759, '01': 2414, '10': 1544, '11': 1475}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 2330, '01': 1748, '10': 2377, '11': 1737}
# ...

# %%
plot_histogram( [DADOS_1, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";   DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit2, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";    DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit2, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";    DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit2, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";     DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit2, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago"; DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit2, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 2487, '01': 2242, '10': 2049, '11': 1414}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 2318, '01': 2032, '10': 1965, '11': 1877}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 2084, '01': 2239, '10': 2388, '11': 1481}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 2392, '01': 2261, '10': 1904, '11': 1635}
# ...

# %%
plot_histogram( [DADOS_2, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";   DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit3, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";    DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit3, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";    DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit3, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";     DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit3, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago"; DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit3, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 2211, '01': 2349, '10': 1930, '11': 1702}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 2521, '01': 2048, '10': 1880, '11': 1743}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 2183, '01': 2238, '10': 2130, '11': 1641}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 2575, '01': 1954, '10': 2016, '11': 1647}
# ...

# %%
plot_histogram( [DADOS_3, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";  DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit4, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";   DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit4, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";   DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit4, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";    DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit4, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago";DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit4, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 4460, '01': 109, '10': 3398, '11': 225}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 4032, '01': 599, '10': 3101, '11': 460}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 4108, '01': 200, '10': 3628, '11': 256}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 4179, '01': 231, '10': 3658, '11': 124}
# ...

# %%
plot_histogram( [DADOS_4, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";  DADOS_manila    = SIMULADOR_REMOTO(QC_QFT_2qubit5, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";   DADOS_quito     = SIMULADOR_REMOTO(QC_QFT_2qubit5, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";   DADOS_belem     = SIMULADOR_REMOTO(QC_QFT_2qubit5, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";    DADOS_lima      = SIMULADOR_REMOTO(QC_QFT_2qubit5, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago";DADOS_santiago  = SIMULADOR_REMOTO(QC_QFT_2qubit5, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 4242, '01': 2249, '10': 191, '11': 1510}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 3766, '01': 2098, '10': 540, '11': 1788}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 3893, '01': 2263, '10': 429, '11': 1607}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 3837, '01': 2517, '10': 228, '11': 1610}
# ...

# %%
plot_histogram( [DADOS_5, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";  DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit6, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";   DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit6, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";   DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit6, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";    DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit6, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago";DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit6, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 269, '01': 3484, '10': 295, '11': 4144}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 643, '01': 3704, '10': 695, '11': 3150}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 423, '01': 3314, '10': 466, '11': 3989}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 247, '01': 3553, '10': 287, '11': 4105}
# ...

# %%
plot_histogram( [DADOS_6, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";  DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit7, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";   DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit7, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";   DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit7, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";    DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit7, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago";DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit7, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 260, '01': 1779, '10': 4305, '11': 1848}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 901, '01': 2007, '10': 3486, '11': 1798}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 1334, '01': 1927, '10': 3183, '11': 1748}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 323, '01': 1601, '10': 4027, '11': 2241}
# ...

# %%
plot_histogram( [DADOS_7, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";   DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit8, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";    DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit8, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";    DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit8, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";     DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit8, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago"; DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit8, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 3769, '01': 134, '10': 4208, '11': 81}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 3878, '01': 540, '10': 3296, '11': 478}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 3525, '01': 212, '10': 4232, '11': 223}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 3802, '01': 96, '10': 4247, '11': 47}
# ...

# %%
plot_histogram( [DADOS_8, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";  DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit9, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";   DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit9, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";   DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit9, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";    DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit9, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago";DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit9, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 4060, '01': 2034, '10': 246, '11': 1852}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 3759, '01': 2132, '10': 548, '11': 1753}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 3744, '01': 2183, '10': 421, '11': 1844}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 4670, '01': 1820, '10': 163, '11': 1539}
# ...

# %%
plot_histogram( [DADOS_9, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";   DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit10, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";    DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit10, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";    DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit10, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";     DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit10, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago"; DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit10, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 451, '01': 4621, '10': 395, '11': 2725}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 763, '01': 3661, '10': 705, '11': 3063}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 344, '01': 4077, '10': 570, '11': 3201}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 269, '01': 4276, '10': 270, '11': 3377}
# ...

# %%
plot_histogram( [DADOS_10, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";    DADOS_manila  = SIMULADOR_REMOTO(QC_QFT_2qubit11, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";     DADOS_quito   = SIMULADOR_REMOTO(QC_QFT_2qubit11, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";     DADOS_belem   = SIMULADOR_REMOTO(QC_QFT_2qubit11, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";      DADOS_lima    = SIMULADOR_REMOTO(QC_QFT_2qubit11, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago";  DADOS_santiago= SIMULADOR_REMOTO(QC_QFT_2qubit11, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 472, '01': 1989, '10': 3581, '11': 2150}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 925, '01': 2309, '10': 3379, '11': 1579}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 407, '01': 1758, '10': 3888, '11': 2139}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 285, '01': 1713, '10': 4172, '11': 2022}
# ...

# %%
plot_histogram( [DADOS_11, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";   DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit12, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";    DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit12, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";    DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit12, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";     DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit12, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago"; DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit12, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 7787, '01': 136, '10': 145, '11': 124}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 6541, '01': 592, '10': 613, '11': 446}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 6989, '01': 231, '10': 792, '11': 180}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 7857, '01': 110, '10': 133, '11': 92}
# ...

# %%
plot_histogram( [DADOS_12, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";   DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit13, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";    DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit13, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";    DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit13, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";     DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit13, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago"; DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit13, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 370, '01': 4072, '10': 362, '11': 3388}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 727, '01': 3643, '10': 588, '11': 3234}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 378, '01': 4036, '10': 410, '11': 3368}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 304, '01': 4398, '10': 285, '11': 3205}
# ...

# %%
plot_histogram( [DADOS_13, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";   DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit14, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";    DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit14, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";    DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit14, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";     DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit14, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago"; DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit14, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 651, '01': 117, '10': 7247, '11': 177}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 1181, '01': 439, '10': 6088, '11': 484}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 644, '01': 196, '10': 7069, '11': 283}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 362, '01': 183, '10': 7525, '11': 122}
# ...

# %%
plot_histogram( [DADOS_14, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";    DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit15, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";     DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit15, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";     DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit15, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";      DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit15, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago";  DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit15, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 250, '01': 3595, '10': 390, '11': 3957}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 588, '01': 3706, '10': 723, '11': 3175}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 262, '01': 3355, '10': 615, '11': 3960}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 221, '01': 3351, '10': 314, '11': 4306}
# ...

# %%
plot_histogram( [DADOS_15, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";    DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit16, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";     DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit16, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";     DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit16, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";      DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit16, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago";  DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit16, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 3988, '01': 1688, '10': 396, '11': 2120}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 3513, '01': 2187, '10': 686, '11': 1806}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 4014, '01': 1522, '10': 495, '11': 2161}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 3926, '01': 1896, '10': 179, '11': 2191}
# ...

# %%
plot_histogram( [DADOS_16, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";    DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit17, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";     DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit17, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";     DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit17, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";      DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit17, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago";  DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit17, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 4242, '01': 1890, '10': 270, '11': 1790}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 3707, '01': 2102, '10': 707, '11': 1676}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 3653, '01': 2019, '10': 561, '11': 1959}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 4501, '01': 1638, '10': 171, '11': 1882}
# ...

# %%
plot_histogram( [DADOS_17, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";    DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit18, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";     DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit18, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";     DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit18, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";      DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit18, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago";  DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit18, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 398, '01': 2416, '10': 3579, '11': 1799}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 882, '01': 2033, '10': 3370, '11': 1907}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 521, '01': 2480, '10': 3453, '11': 1738}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 328, '01': 2382, '10': 3618, '11': 1864}
# ...

# %%
plot_histogram( [DADOS_18, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";    DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit19, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";     DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit19, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";     DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit19, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";      DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit19, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago";  DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit19, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 512, '01': 1872, '10': 3941, '11': 1867}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 944, '01': 1925, '10': 3457, '11': 1866}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 694, '01': 1731, '10': 4091, '11': 1676}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 306, '01': 1845, '10': 4408, '11': 1633}
# ...

# %%
plot_histogram( [DADOS_19, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
BACKEND_NAME = "ibmq_manila";    DADOS_manila   = SIMULADOR_REMOTO(QC_QFT_2qubit20, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_quito";     DADOS_quito    = SIMULADOR_REMOTO(QC_QFT_2qubit20, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_belem";     DADOS_belem    = SIMULADOR_REMOTO(QC_QFT_2qubit20, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_lima";      DADOS_lima     = SIMULADOR_REMOTO(QC_QFT_2qubit20, N_SHOTS, BACKEND_NAME);
BACKEND_NAME = "ibmq_santiago";  DADOS_santiago = SIMULADOR_REMOTO(QC_QFT_2qubit20, N_SHOTS, BACKEND_NAME);
# Out:
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_manila |   status: Successful completion |   success: True
#    get_counts(): {'00': 4796, '01': 1817, '10': 1176, '11': 403}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_quito |   status: Successful completion |   success: True
#    get_counts(): {'00': 3806, '01': 2221, '10': 1406, '11': 759}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_belem |   status: Successful completion |   success: True
#    get_counts(): {'00': 4326, '01': 1775, '10': 1343, '11': 748}
#  ---------- FIM DA FUNCAO 'SIMULADOR_REMOTO()'----------
# Job Status: job has successfully run
#  RESULTS:
#    backend_name: ibmq_lima |   status: Successful completion |   success: True
#    get_counts(): {'00': 4416, '01': 1903, '10': 1346, '11': 527}
# ...

# %%
plot_histogram( [DADOS_20, DADOS_manila, DADOS_quito, DADOS_belem, DADOS_lima, DADOS_santiago],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = False, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %% [markdown]
# ## TESTE: Executando vários circuitos na mesma máquina
#
# * OBS.: Há errado na lista de circuito enviados

# %%
provider=IBMQ.get_provider('ibm-q')

# %%
from qiskit import execute

# %%
quantum_computer=provider.get_backend('ibmq_manila')

execute_circuit_manila=execute([QC_QFT_2qubit0, QC_QFT_2qubit1, QC_QFT_2qubit2, QC_QFT_2qubit3, QC_QFT_2qubit4, QC_QFT_2qubit5, QC_QFT_2qubit6, QC_QFT_2qubit7, QC_QFT_2qubit8, QC_QFT_2qubit9, QC_QFT_2qubit10, QC_QFT_2qubit11, QC_QFT_2qubit12, QC_QFT_2qubit13, QC_QFT_2qubit14, QC_QFT_2qubit15, QC_QFT_2qubit16, QC_QFT_2qubit17, QC_QFT_2qubit18, QC_QFT_2qubit19, QC_QFT_2qubit20], backend=quantum_computer, shots=2**(13))

result_manila=execute_circuit_manila.result()

# %%
quantum_computer=provider.get_backend('ibmq_quito')

execute_circuit_quito=execute([QC_QFT_2qubit0, QC_QFT_2qubit1, QC_QFT_2qubit2, QC_QFT_2qubit3, QC_QFT_2qubit4, QC_QFT_2qubit5, QC_QFT_2qubit6, QC_QFT_2qubit7, QC_QFT_2qubit8, QC_QFT_2qubit9, QC_QFT_2qubit10, QC_QFT_2qubit11, QC_QFT_2qubit12, QC_QFT_2qubit13, QC_QFT_2qubit14, QC_QFT_2qubit15, QC_QFT_2qubit16, QC_QFT_2qubit17, QC_QFT_2qubit18, QC_QFT_2qubit19, QC_QFT_2qubit20], backend=quantum_computer, shots=2**(13))

result_quito=execute_circuit_quito.result()

# %%
plot_histogram( [DADOS_0, result_manila.get_counts(QC_QFT_2qubit0), result_quito.get_counts(QC_QFT_2qubit0), result_belem.get_counts(QC_QFT_2qubit0), result_lima.get_counts(QC_QFT_2qubit0), result_santiago.get_counts(QC_QFT_2qubit0)],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = True, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )
# Out:
# C:\Users\warle\anaconda3\lib\site-packages\qiskit\result\result.py:396: UserWarning: Result object contained multiple results matching name "QFT_2qubit", only first match will be returned. Use an integer index to retrieve results for all entries.
#   warnings.warn(

# %%
plot_histogram( [DADOS_1, result_manila.get_counts(QC_QFT_2qubit1), result_quito.get_counts(QC_QFT_2qubit1), result_belem.get_counts(QC_QFT_2qubit1), result_lima.get_counts(QC_QFT_2qubit1), result_santiago.get_counts(QC_QFT_2qubit1)],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = True, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
plot_histogram( [DADOS_2, result_manila.get_counts(QC_QFT_2qubit2), result_quito.get_counts(QC_QFT_2qubit2), result_belem.get_counts(QC_QFT_2qubit2), result_lima.get_counts(QC_QFT_2qubit2), result_santiago.get_counts(QC_QFT_2qubit2)],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = True, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
plot_histogram( [DADOS_3, result_manila.get_counts(QC_QFT_2qubit3), result_quito.get_counts(QC_QFT_2qubit3), result_belem.get_counts(QC_QFT_2qubit3), result_lima.get_counts(QC_QFT_2qubit3), result_santiago.get_counts(QC_QFT_2qubit3)],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = True, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
plot_histogram( [DADOS_4, result_manila.get_counts(QC_QFT_2qubit4), result_quito.get_counts(QC_QFT_2qubit4), result_belem.get_counts(QC_QFT_2qubit4), result_lima.get_counts(QC_QFT_2qubit4), result_santiago.get_counts(QC_QFT_2qubit4)],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = True, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
plot_histogram( [DADOS_20, result_manila.get_counts(QC_QFT_2qubit20), result_quito.get_counts(QC_QFT_2qubit20), result_belem.get_counts(QC_QFT_2qubit20), result_lima.get_counts(QC_QFT_2qubit20), result_santiago.get_counts(QC_QFT_2qubit20)],legend =['qasm', 'manila', 'quito', 'belem', 'lima', 'santiago'], bar_labels = True, color=['blue', 'red', 'green', 'yellow', 'gray', 'purple'], figsize = (10, 6) )

# %%
quantum_computer=provider.get_backend('ibmq_manila')

execute_circuit_manila=execute([QC_QFT_2qubit0, QC_QFT_2qubit1, QC_QFT_2qubit2, QC_QFT_2qubit3, QC_QFT_2qubit4], backend=quantum_computer, shots=2**(13))

result_manila=execute_circuit_manila.result()

# %%
quantum_computer=provider.get_backend('ibmq_quito')

execute_circuit_quito=execute([QC_QFT_2qubit0, QC_QFT_2qubit1, QC_QFT_2qubit2, QC_QFT_2qubit3, QC_QFT_2qubit4], backend=quantum_computer, shots=2**(13))

result_quito=execute_circuit_quito.result()

# %%
quantum_computer=provider.get_backend('ibmq_belem')

execute_circuit_belem=execute([QC_QFT_2qubit0, QC_QFT_2qubit1, QC_QFT_2qubit2, QC_QFT_2qubit3, QC_QFT_2qubit4], backend=quantum_computer, shots=2**(13))

result_belem=execute_circuit_belem.result()

# %%
plot_histogram(result_manila.get_counts(QC_QFT_2qubit1))

# %%
plot_histogram(result_belem.get_counts(QC_QFT_2qubit1))

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# Out:
# C:\Users\warle\anaconda3\lib\site-packages\qiskit\aqua\__init__.py:86: DeprecationWarning: The package qiskit.aqua is deprecated. It was moved/refactored to qiskit-terra For more information see <https://github.com/Qiskit/qiskit-aqua/blob/main/README.md#migration-guide>
#   warn_package('aqua', 'qiskit-terra')
# ...
